# %% [markdown]
# <a href="https://colab.research.google.com/github/sagsshakya/Machine-Learning/blob/master/Machine%20Learning%20LAB/Q19_Clustering_and_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q19. Clustering and EDA.
# ### Problem Statement:
#     Multidimensional data analysis in Python - import, Clustering, Exploratory Data Analysis.

# %% [markdown]
# # Importing necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the IRIS dataset.

# %%
# Loading the dataset.
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
Y = iris.target

# Taking the first two columns for X.
X = X[:,:2]

# %% [markdown]
# # Implementing K - Means Clustering algorithm.

# %%
from sklearn.cluster import KMeans
clus = KMeans(n_clusters=3)
clus.fit(X)

# Print Centroids.
print(clus.cluster_centers_.round(2))
# Out:
# [[5.01 3.43]
#  [5.77 2.69]
#  [6.81 3.07]]

# %% [markdown]
# # Exploratory Data Analysis on the data.

# %%
# EDA on the data based on old labels.
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.scatter(X[:, 0], X[:, 1], c = Y)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

# EDA on the data based on new labels.
plt.subplot(1,2,2)
plt.scatter(X[:, 0], X[:, 1], c = new_labels)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.show()
